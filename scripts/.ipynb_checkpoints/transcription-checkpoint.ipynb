# %%
import torch
from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
from peft import PeftModel

device = "cuda" if torch.cuda.is_available() else "cpu"
torch_dtype = torch.float16 if torch.cuda.is_available() else torch.float32
model_id = "openai/whisper-medium.en"

lora_dir = "./whisper-docvoice-lora/final_adapter" 

# Load the base Whisper model
base_model = AutoModelForSpeechSeq2Seq.from_pretrained(
    model_id,
    torch_dtype=torch_dtype,
    low_cpu_mem_usage=True
)

processor = AutoProcessor.from_pretrained(model_id)

# Load + merge LoRA
model = PeftModel.from_pretrained(base_model, lora_dir)
model = model.merge_and_unload()   # Combine LoRA weights into the main model
model.eval()

model.to(device)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       2 from transformers import AutoModelForSpeechSeq2Seq, AutoProcessor, pipeline
#       3 from peft import PeftModel
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\__init__.py:2150
#    2143 from torch._compile import _disable_dynamo  # usort: skip
#    2145 ################################################################################
#    2146 # Import interface functions defined in Python
#    2147 ################################################################################
#    2148
#    2149 # needs to be after the above ATen bindings so we can overwrite from Python side
# -> 2150 from torch import _VF as _VF, functional as functional  # usort: skip
#    2151 from torch.functional import *  # usort: skip # noqa: F403
#    2153 ################################################################################
#    2154 # Remove unnecessary members
#    2155 ################################################################################
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\functional.py:8
#       5 from typing import Any, Optional, TYPE_CHECKING, Union
#       7 import torch
# ----> 8 import torch.nn.functional as F
#       9 from torch import _VF, Tensor
#      10 from torch._C import _add_docstr
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\__init__.py:8
#       1 # mypy: allow-untyped-defs
#       2 from torch.nn.parameter import (  # usort: skip
#       3     Buffer as Buffer,
#       4     Parameter as Parameter,
#       5     UninitializedBuffer as UninitializedBuffer,
#       6     UninitializedParameter as UninitializedParameter,
#       7 )
# ----> 8 from torch.nn.modules import *  # usort: skip # noqa: F403
#       9 from torch.nn import (
#      10     attention as attention,
#      11     functional as functional,
#    (...)     16     utils as utils,
#      17 )
#      18 from torch.nn.parallel import DataParallel as DataParallel
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\__init__.py:1
# ----> 1 from .module import Module  # usort: skip
#       2 from .linear import Bilinear, Identity, LazyLinear, Linear  # usort: skip
#       3 from .activation import (
#       4     CELU,
#       5     ELU,
#    (...)     32     Threshold,
#      33 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:17
#      15 from torch._prims_common import DeviceLikeType
#      16 from torch.nn.parameter import Buffer, Parameter
# ---> 17 from torch.utils._python_dispatch import is_traceable_wrapper_subclass
#      18 from torch.utils.hooks import BackwardHook, RemovableHandle
#      21 __all__ = [
#      22     "register_module_forward_pre_hook",
#      23     "register_module_forward_hook",
#    (...)     30     "Module",
#      31 ]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_python_dispatch.py:298
#     294         return func(*args, **kwargs)
#     297 # Subtypes which have __tensor_flatten__ and __tensor_unflatten__.
# --> 298 class TensorWithFlatten(Protocol):
#     299     def __tensor_flatten__(self) -> tuple[Sequence[str], object]:
#     300         ...
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\utils\_python_dispatch.py:339, in TensorWithFlatten()
#     333 def dim(self) -> int:
#     334     ...
#     336 @overload
#     337 def to(
#     338     self,
# --> 339     dtype: torch.types._dtype,
#     340     non_blocking: bool = False,
#     341     copy: bool = False,
#     342     *,
#     343     memory_format: Optional[torch.memory_format] = None,
#     344 ) -> torch.Tensor:
#     345     ...
#     347 @overload
#     348 def to(
#     349     self,
#    (...)    355     memory_format: Optional[torch.memory_format] = None,
#     356 ) -> torch.Tensor:
#
# AttributeError: partially initialized module 'torch' has no attribute 'types' (most likely due to a circular import)

# %%
pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    tokenizer=processor.tokenizer,
    feature_extractor=processor.feature_extractor,
    chunk_length_s=30,      
    batch_size=8,           
    torch_dtype=torch_dtype,
    device=device,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pipe = pipeline(
#       2     "automatic-speech-recognition",
#       3     model=model,
#       4     tokenizer=processor.tokenizer,
#       5     feature_extractor=processor.feature_extractor,
#       6     chunk_length_s=30,
#       7     batch_size=8,
#       8     torch_dtype=torch_dtype,
#       9     device=device,
#      10 )
#
# NameError: name 'pipeline' is not defined

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import numpy as np
import tempfile

def record(seconds=5, samplerate=16000):
    print("Recording...")
    audio = sd.rec(int(seconds * samplerate), samplerate=samplerate, channels=1, dtype="float32")
    sd.wait()
    print("Recording finished")
    audio = (audio * 32767).astype(np.int16)

    tmp = tempfile.NamedTemporaryFile(delete=False, suffix=".wav")
    write(tmp.name, samplerate, audio)
    return tmp.name

while True:
    audio_path = record(seconds=5)
    result = pipe(audio_path)
    print("👉", result["text"])
